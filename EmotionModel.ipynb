# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('dataset/datasetFER_2013.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Emotion                                         PixelValue  \
# 0           0        0  [46, 34, 26, 23, 12, 32, 35, 26, 26, 38, 71, 9...
# 1           1        0  [55, 33, 54, 32, 26, 21, 50, 29, 38, 45, 79, 7...
# 2           2        0  [123, 123, 126, 131, 124, 69, 109, 149, 159, 1...
# 3           3        0  [255, 255, 255, 255, 255, 255, 255, 255, 255, ...
# 4           4        0  [127, 121, 124, 137, 123, 118, 120, 111, 111, ...
#
#       DataType
# 0  PrivateTest
# 1  PrivateTest
# 2  PrivateTest
# 3  PrivateTest
# 4  PrivateTest

# %%
df.head(10)
# Out:
#    Unnamed: 0  Emotion                                         PixelValue  \
# 0           0        0  [46, 34, 26, 23, 12, 32, 35, 26, 26, 38, 71, 9...
# 1           1        0  [55, 33, 54, 32, 26, 21, 50, 29, 38, 45, 79, 7...
# 2           2        0  [123, 123, 126, 131, 124, 69, 109, 149, 159, 1...
# 3           3        0  [255, 255, 255, 255, 255, 255, 255, 255, 255, ...
# 4           4        0  [127, 121, 124, 137, 123, 118, 120, 111, 111, ...
# 5           5        0  [248, 243, 254, 255, 255, 252, 253, 254, 255, ...
# 6           6        0  [49, 36, 46, 53, 52, 48, 56, 40, 47, 72, 57, 7...
# 7           7        0  [225, 230, 230, 232, 216, 197, 213, 213, 208, ...
# 8           8        0  [118, 12, 17, 12, 5, 7, 11, 6, 6, 21, 59, 70, ...
# 9           9        0  [255, 255, 255, 255, 255, 255, 255, 255, 255, ...
#
#       DataType
# 0  PrivateTest
# 1  PrivateTest
# 2  PrivateTest
# 3  PrivateTest
# 4  PrivateTest
# 5  PrivateTest
# 6  PrivateTest
# 7  PrivateTest
# ...

# %%
len(df)
# Out:
# 35887

# %% [markdown]
# ***PREPROCESSING***

# %%
#Total number of unique Emotions
df.Emotion.unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=int64)

# %%
#Let's read the image from Pixel Value
#1. Convert the list of pixelvalue to np array
#2. Resize the array to 48,48 (input value)
df_PxLs=df.PixelValue[0][1:-1]

# %%
#print(df_PxLs)

# %%
#df_PxLs.split(',')

# %%
np.array(df_PxLs.split(','))
# Out:
# array(['46', ' 34', ' 26', ..., ' 165', ' 180', ' 189'], dtype='<U4')

# %%
SampleImg_array = np.array(df_PxLs.split(',')).reshape(48,48)

# %%
print(SampleImg_array)
# Out:
# [['46' ' 34' ' 26' ... ' 10' ' 13' ' 22']
#  [' 50' ' 28' ' 21' ... ' 11' ' 10' ' 21']
#  [' 50' ' 27' ' 15' ... ' 22' ' 24' ' 22']
#  ...
#  [' 208' ' 179' ' 108' ... ' 191' ' 205' ' 204']
#  [' 212' ' 198' ' 149' ... ' 181' ' 200' ' 204']
#  [' 208' ' 201' ' 171' ... ' 165' ' 180' ' 189']]

# %%
#plt.imshow(SampleImg_array)
#Strin values should be converted to float like '48' to 48.00...
plt.imshow(SampleImg_array.astype('float'))

# %%
df_PxLs=df.PixelValue[1][1:-1]
np.array(df_PxLs.split(','))
SampleImg_array = np.array(df_PxLs.split(',')).reshape(48,48)
plt.imshow(SampleImg_array.astype('float'))

# %%
#print(np.array(df.PixelValue[2][1:-2].split(',')).reshape(48,48).astype('float'))

df_PxLs=df.PixelValue[2][1:-1]
#print(df_PxLs)
#print(df.PixelValue[2])

np.array(df_PxLs.split(','))

SampleImg_array = np.array(df.PixelValue[2][1:-1].split(',')).reshape(48,48)
plt.imshow(SampleImg_array.astype('float'))

# %%
df_PxLs=df.PixelValue[3][1:-1]
#print(df_PxLs)
#print(df.PixelValue[2])

np.array(df_PxLs.split(','))

SampleImg_array = np.array(df_PxLs.split(',')).reshape(48,48)
plt.imshow(SampleImg_array.astype('float'))

# %%
#Label Encoder array
#Lets us take our emotion names in to dictionary for demo purpose.
label_to_text={'0':'angry','1':'disgust','2':'fear','3':'happy','4':'neutral','5':'sad','6':'surprise'}

# %%
import matplotlib.pyplot as plt
fig = plt.figure(1, (14, 14))
k = 0
for label in df.Emotion.unique():
    #print(label)
    for j in range(3):
        px = df[df.Emotion==label].PixelValue.iloc[k][1:-2]
        try:
            px = np.array(px.split(',')).reshape(48, 48).astype('float32')
            k += 1
            ax = plt.subplot(7, 7, k)
            ax.imshow(px)
            ax.set_xticks([])
            ax.set_yticks([])
            label_to_text={'0':'angry','1':'disgust','2':'fear','3':'happy','4':'neutral','5':'sad','6':'surprise'}
            ax.set_title(label_to_text[str(label)])
            pyplot.tight_layout()
        except:
            "Value Error"

# %%
for label in df.Emotion.unique():
    #print(label)
    k = 0
    
    px = df[df.Emotion==label].PixelValue.iloc[k][1:-2]
    #print(k)
    #print(px)
    px_array = np.array(px.split(',')).reshape(48,48)
    #print(px_array.astype('float'))
    k +=1
    plt.imshow(px_array.astype('float'))

# %%
k = 0
for label in df.Emotion.unique():
    try:
        px = df[df.Emotion==label].PixelValue.iloc[k][1:-2]
        #print(k)
        #print(px)
        px_array = np.array(px.split(',')).reshape(48,48)
        #print(px_array.astype('float'))
        k +=1
        plt.imshow(px_array.astype('float'))
    except:
        "ValueError"

# %%
#Apply resizing to all pixel values to read the images
Image_array = df.PixelValue.apply(lambda x:np.array(x[1:-1].split(',')).reshape(48,48,1).astype('float'))

# %%
Image_array.shape
#Looks like it is not staked up
#Lets apply stack command
# Out:
# (35887,)

# %%
Image_array = np.stack(Image_array,axis = 0)

# %%
Image_array.shape
# Out:
# (35887, 48, 48, 1)

# %%
#Lets plot the nth element from Image_array
plt.imshow(Image_array[3100])

# %%
#Lets read our target labels also in to the numpy array.
Labels = df.Emotion.values
print(Labels)
Labels.shape
# Out:
# [0 0 0 ... 6 6 6]
# (35887,)

# %%
# Now our data is ready to train our neural network.

# %% [markdown]
# ***Splitting the data in to training and testing set***

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(Image_array,Labels,train_size=.9,test_size=.1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_train.shape)
# Out:
# (32298, 48, 48, 1)
# (3589, 48, 48, 1)
# (32298,)
# (32298,)

# %%
#Scaling
X_train= X_train/255
X_test= X_test/255

# %%
print(X_train[0])
# Out:
# [[[0.36078431]
#   [0.38039216]
#   [0.25490196]
#   ...
#   [0.05098039]
#   [0.04705882]
#   [0.05098039]]
#
#  [[0.41960784]
#   [0.2627451 ]
#   [0.15294118]
#   ...
#   [0.05882353]
#   [0.06666667]
#   [0.07843137]]
#
#  [[0.30196078]
#   [0.16862745]
#   [0.07843137]
#   ...
#   [0.08235294]
#   [0.07843137]
#   [0.07843137]]
#
#  ...
#
#  [[0.38823529]
#   [0.37647059]
#   [0.36470588]
#   ...
#   [0.46666667]
#   [0.41176471]
#   [0.41176471]]
#
#  [[0.36862745]
#   [0.38039216]
#   [0.38823529]
#   ...
#   [0.45882353]
#   [0.45098039]
#   [0.46666667]]
#
#  [[0.32156863]
#   [0.36862745]
#   [0.4       ]
#   ...
#   [0.43529412]
#   [0.43137255]
#   [0.39607843]]]

# %% [markdown]
# ***Notes***

# %% [markdown]
# STRIDE: is the number of pixels shifts over the input matrix. When the stride is 1 then we move the filters to 1 pixel at a time. When the stride is 2 then we move the filters to 2 pixels at a time and so on. The below figure shows convolution would work with a stride of 2.

# %%
#Very good tutorial
#****https://medium.com/@RaghavPrabhu/understanding-of-convolutional-neural-network-cnn-deep-learning-99760835f148***#

# %%
#https://keras.io/api/layers/pooling_layers/max_pooling2d/
#https://keras.io/api/layers/convolution_layers/convolution2d/

# %% [markdown]
# ***Creating a base model***

# %%
import tensorflow as tf

# %%
#Ref:https://keras.io/api/layers/convolution_layers/convolution2d/
#Number of filter = 32
#(3,3) conv filter
#As our input image is of size(48,48)
BaseModel = tf.keras.models.Sequential([tf.keras.layers.Conv2D(32,(3, 3), activation='relu', input_shape=(48,48,1)),
                                        tf.keras.layers.MaxPool2D((2,2),strides=None),
                                        tf.keras.layers.BatchNormalization()])

# %%
#Doubt: strides=None is 2?

# %% [markdown]
# ***CONVOLUTION LAYER OUTPUT: ***
# #Ref:https://medium.com/@RaghavPrabhu/understanding-of-convolutional-neural-network-cnn-deep-learning-99760835f148
#
# input image = (48,48,1)=(h,w,d);
# filter/kernel_size = (3,3,1)=(fh,fw,fd);
# output = (h-fh+1),(w-fw+1),1;
# =>((48-3+1),(48-3+1),1);
# =>(46,46,1);
# *Because number of filters are 32
# output should be equal to (46,46,32)

# %% [markdown]
# ***MaxPool2D Output***

# %% [markdown]
# #Ref:https://dingyan89.medium.com/calculating-parameters-of-convolutional-and-fully-connected-layers-with-keras-186590df36c6
#
# input = (46,46,1)
# filter= (2,2,1)
# if strides=(1,1)
# output=(45,45,32)
# if stride == (2,2)/None;
# then output = [(46-2)/2+1,(46-2)/2+1,32]
# Output = (23,23,32)

# %% [markdown]
# ***Batch Normalization Layer output***

# %% [markdown]
# #Ref: https://keras.io/api/layers/normalization_layers/batch_normalization/
# We are Normalizing each channel.
#
# During training (i.e. when using fit() or when calling the layer/model with the argument training=True), the layer normalizes its output using the mean and standard deviation of the current batch of inputs. That is to say, for each channel being normalized, the layer returns gamma * (batch - mean(batch)) / sqrt(var(batch) + epsilon) + beta, where:
#
# epsilon is small constant (configurable as part of the constructor arguments)
# gamma is a learned scaling factor (initialized as 1), which can be disabled by passing scale=False to the constructor.
# beta is a learned offset factor (initialized as 0), which can be disabled by passing center=False to the constructor.

# %%
#Doubt: strides=None is 2?

# %%
BaseModel.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_21 (Conv2D)           (None, 46, 46, 32)        320
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 23, 23, 32)        0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 23, 23, 32)        128
# ...
# Total params: 448
# Trainable params: 384
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# #Adding Dense Layer
# #A Dense layer feeds all outputs from the previous layer to all its neurons, each neuron providing one output to the next layer. It's the most basic layer in neural networks.

# %%
BaseModel = tf.keras.models.Sequential([tf.keras.layers.Conv2D(32,(3, 3), activation='relu', input_shape=(48,48,1)),
                                        tf.keras.layers.MaxPool2D((2,2),strides=None),
                                        tf.keras.layers.BatchNormalization(),
                                       
                                        tf.keras.layers.Dense(128,activation= 'relu')])

# %%
BaseModel.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_22 (Conv2D)           (None, 46, 46, 32)        320
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 23, 23, 32)        0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 23, 23, 32)        128
# _________________________________________________________________
# dense_7 (Dense)              (None, 23, 23, 128)       4224
# ...
# Total params: 4,672
# Trainable params: 4,608
# Non-trainable params: 64
# _________________________________________________________________

# %%
#Since it is a classification problem,we have 7 classes we need to add another denselayer, with activation 7 activation unit= softmax

# %%
BaseModel = tf.keras.models.Sequential([tf.keras.layers.Conv2D(32,(3, 3), activation='relu', input_shape=(48,48,1)),
                                        tf.keras.layers.MaxPool2D((2,2),strides=None),
                                        tf.keras.layers.BatchNormalization(),
                                       
                                        tf.keras.layers.Dense(128,activation= 'relu'),
                                        tf.keras.layers.Dense(7,activation='softmax')])

# %%
BaseModel.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_23 (Conv2D)           (None, 46, 46, 32)        320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 23, 23, 32)        0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 23, 23, 32)        128
# _________________________________________________________________
# dense_8 (Dense)              (None, 23, 23, 128)       4224
# _________________________________________________________________
# dense_9 (Dense)              (None, 23, 23, 7)         903
# ...
# Total params: 5,575
# Trainable params: 5,511
# Non-trainable params: 64
# _________________________________________________________________

# %%
#output :dense_4 (Dense)              (None, 23, 23, 7)         903    
#Because of this we need to add flatten layer once coming out of maxpool

# %%
BaseModel = tf.keras.models.Sequential([tf.keras.layers.Conv2D(32,(3, 3), activation='relu', input_shape=(48,48,1)),
                                        tf.keras.layers.MaxPool2D((2,2),strides=None),
                                        tf.keras.layers.BatchNormalization(),
                                        
                                        tf.keras.layers.Flatten(),
                                       
                                        tf.keras.layers.Dense(128,activation= 'relu'),
                                        tf.keras.layers.Dense(7,activation='softmax')])

# %%
BaseModel.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_24 (Conv2D)           (None, 46, 46, 32)        320
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 23, 23, 32)        0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 23, 23, 32)        128
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16928)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               2166912
# _________________________________________________________________
# dense_11 (Dense)             (None, 7)                 903
# ...
# Total params: 2,168,263
# Trainable params: 2,168,199
# Non-trainable params: 64
# ...

# %% [markdown]
# #Ref:https://towardsdatascience.com/the-most-intuitive-and-easiest-guide-for-convolutional-neural-network-3607be47480
# #Flatten Layer:
# #flatten function flattens the multi-dimensional input tensors into a single dimension, so you can model your input layer and build your neural network model, then pass those data into every single neuron of the model effectively.

# %% [markdown]
# ***Compile BaseModel***

# %%
BaseModel.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001),
                 loss = 'sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# RMSprop is a gradient-based optimization technique used in training neural networks. This normalization balances the step size (momentum), decreasing the step for large gradients to avoid exploding and increasing the step for small gradients to avoid vanishing.

# %% [markdown]
# ***Save Model***

# %%
'''# save the model to disk
filename = 'finalized_model.sav'
pickle.dump(model, open(filename, 'wb'))
 
# some time later...
 
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, Y_test)
print(result)'''
# Out:
# "# save the model to disk\nfilename = 'finalized_model.sav'\npickle.dump(model, open(filename, 'wb'))\n \n# some time later...\n \n# load the model from disk\nloaded_model = pickle.load(open(filename, 'rb'))\nresult = loaded_model.score(X_test, Y_test)\nprint(result)"

# %%
#Creating checkpoint directory

import os
try:
    os.mkdir('checkpoint')
except:
    pass

# %%
file_name = 'BaseModel.h5'
checkpoint_path =os.path.join('checkpoint',file_name)

call_backs = tf.keras.callbacks.ModelCheckpoint(filepath =checkpoint_path,
                                               monitor ='val_accuracy',
                                               verbose =1,
                                               save_freq='epoch',
                                               save_best_only = True,
                                               save_weights_only= False,
                                               mode = 'max')

# %% [markdown]
# ***Training***

# %%
#learn_rate = ReduceLROnPlateau(monitor='val_loss', factor=0.1,patience=2, min_lr=0.0008, mode='auto')
#cp = ModelCheckpoint("/content/drive/MyDrive/csce5210/model_weights.h5", monitor='val_accuracy',save_weights_only=True, mode='max', verbose=1)
#cb = [PlotLossesKerasTF(), cp, learn_rate]

# %%
BaseModel.fit(X_train,y_train,epochs=20,validation_split = 0.1,callbacks=call_backs)
# Out:
# Epoch 1/20
# 909/909 [==============================] - 69s 74ms/step - loss: 1.5877 - accuracy: 0.3957 - val_loss: 1.4798 - val_accuracy: 0.4260
#
# Epoch 00001: val_accuracy improved from -inf to 0.42601, saving model to checkpoint\BaseModel.h5
# Epoch 2/20
# 909/909 [==============================] - 69s 75ms/step - loss: 1.2572 - accuracy: 0.5322 - val_loss: 1.4032 - val_accuracy: 0.4768
#
# Epoch 00002: val_accuracy improved from 0.42601 to 0.47678, saving model to checkpoint\BaseModel.h5
# Epoch 3/20
# 909/909 [==============================] - 67s 74ms/step - loss: 1.0398 - accuracy: 0.6264 - val_loss: 1.4205 - val_accuracy: 0.4913
#
# Epoch 00003: val_accuracy improved from 0.47678 to 0.49133, saving model to checkpoint\BaseModel.h5
# Epoch 4/20
# 909/909 [==============================] - 66s 73ms/step - loss: 0.8575 - accuracy: 0.7018 - val_loss: 1.4239 - val_accuracy: 0.4876
#
# Epoch 00004: val_accuracy did not improve from 0.49133
# Epoch 5/20
# ...

# %% [markdown]
# ***Evaluate***

# %%
y_pred = BaseModel.predict(X_test)

# %%
y_pred[0]
# Out:
# array([9.9879670e-01, 8.8032515e-18, 3.9337397e-07, 8.2125112e-08,
#        1.2000033e-03, 2.7805165e-06, 5.8212934e-10], dtype=float32)

# %%
Percentage_emotion = round((max(y_pred[0])*100),2)
print(Percentage_emotion)
# Out:
# 99.88

# %%
y_list = list(y_pred[0])

# %%
y_list
#print(max(y_list))
# Out:
# 0.9987967

# %%
y_list[0]
# Out:
# 0.9987967

# %%
for i in range(0,7):
    #print(i)
    if y_list[i]==max(y_list):
        #print(label_to_text['0'])
        print(label_to_text[str(i)],"=",y_list[i],"%")
# Out:
# angry = 0.9987967 %

# %%
y_pred.argmax()
# Out:
# 185

# %%
#********#
X_test[0]
plt.imshow(X_test[0])
label_to_text.keys()
y=str(y_test[0])
print("Original_label==",label_to_text[y])

for i in range(0,7):
    #print(i)
    if y_list[i]==max(y_list):
        #print(label_to_text['0'])
        print("Predicted_label==",label_to_text[str(i)],"Emotion_percentage",round((y_list[i]*100),2),"%")
# Out:
# Original_label== neutral
# Predicted_label== angry Emotion_percentage 99.88 %

# %% [markdown]
# Increasing the number of hidden layers of the artificial neural network would increase the ability of the system to effectively learn from the input and update its weight according to the statistics of the input data in order to achieve the desire signal and reduce the error of the system.

# %%
'''#cb = [PlotLossesKerasTF(), cp, learn_rate]
history = BaseModel.fit(X, Y, validation_split=0.33, epochs=20, batch_size=10, verbose=0)
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()'''

# %%
'''import pickle
filename = 'BaseModel1.h5'
pickle.dump(BaseModel, open(filename, 'wb'))'''
# Out:
# "import pickle\nfilename = 'BaseModel1.h5'\npickle.dump(BaseModel, open(filename, 'wb'))"

# %%
'''# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, Y_test)
print(result)'''

# %% [markdown]
# ***BaseModel2***

# %%
BaseModel2 = tf.keras.models.Sequential([tf.keras.layers.Conv2D(32,(3, 3), activation='relu', input_shape=(48,48,1)),
                                        tf.keras.layers.MaxPool2D((2,2),strides=None),
                                        tf.keras.layers.BatchNormalization(),
                                        
                                        tf.keras.layers.Conv2D(64,(3, 3), activation='relu', input_shape=(48,48,1)),
                                        tf.keras.layers.MaxPool2D((2,2),strides=None),
                                        tf.keras.layers.BatchNormalization(),
                                        
                                        tf.keras.layers.Conv2D(128,(3, 3), activation='relu', input_shape=(48,48,1)),
                                        tf.keras.layers.MaxPool2D((2,2),strides=None),
                                        tf.keras.layers.BatchNormalization(),
                                        
                                        tf.keras.layers.Conv2D(256,(3, 3), activation='relu', input_shape=(48,48,1)),
                                        tf.keras.layers.MaxPool2D((2,2),strides=None),
                                        tf.keras.layers.BatchNormalization(),
                                        
                                        
                                        tf.keras.layers.Flatten(),
                                       
                                        tf.keras.layers.Dense(128,activation= 'relu'),
                                        tf.keras.layers.Dense(7,activation='softmax')])

# %%
file_name = 'BaseModel2.h5'
checkpoint_path =os.path.join('checkpoint',file_name)

call_backs = tf.keras.callbacks.ModelCheckpoint(filepath =checkpoint_path,
                                               monitor ='val_accuracy',
                                               verbose =1,
                                               save_freq='epoch',
                                               save_best_only = False,
                                               save_weights_only= False,
                                               mode = 'max')

# %%
BaseModel2.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001),
                 loss = 'sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = BaseModel2.fit(X_train,y_train,epochs=20,validation_split = 0.2,callbacks=call_backs)
# Out:
# Epoch 1/20
# 808/808 [==============================] - 90s 106ms/step - loss: 1.5038 - accuracy: 0.4263 - val_loss: 1.4260 - val_accuracy: 0.4621
#
# Epoch 00001: saving model to checkpoint\BaseModel2.h5
# Epoch 2/20
# 808/808 [==============================] - 88s 109ms/step - loss: 1.2707 - accuracy: 0.5232 - val_loss: 1.3732 - val_accuracy: 0.4824
#
# Epoch 00002: saving model to checkpoint\BaseModel2.h5
# Epoch 3/20
# 808/808 [==============================] - 89s 110ms/step - loss: 1.1169 - accuracy: 0.5912 - val_loss: 1.3347 - val_accuracy: 0.5019
#
# Epoch 00003: saving model to checkpoint\BaseModel2.h5
# Epoch 4/20
# 808/808 [==============================] - 100s 124ms/step - loss: 0.9789 - accuracy: 0.6468 - val_loss: 1.3098 - val_accuracy: 0.5203
#
# Epoch 00004: saving model to checkpoint\BaseModel2.h5
# Epoch 5/20
# 808/808 [==============================] - 99s 123ms/step - loss: 0.8470 - accuracy: 0.7047 - val_loss: 1.3133 - val_accuracy: 0.5223
#
# ...

# %%
y_pred2 = BaseModel2.predict(X_test)

# %%
#********#
y_list = list(y_pred2[0])
X_test[0]
plt.imshow(X_test[0])
label_to_text.keys()
y=str(y_test[0])
print("Original_label==",label_to_text[y])

for i in range(0,7):
    #print(i)
    if y_list[i]==max(y_list):
        #print(label_to_text['0'])
        print("Predicted_label==",label_to_text[str(i)],"\nEmotion_percentage",round((y_list[i]*100),2),"%")
# Out:
# Original_label== neutral
# Predicted_label== happy
# Emotion_percentage 68.63 %

# %% [markdown]
# ***MODEL Save and Load:***
# https://www.tensorflow.org/tutorials/keras/save_and_load

# %%
# Recreate the exact same model, including its weights and the optimizer
import os
file_name = 'BaseModel2.h5'
checkpoint_path =os.path.join('checkpoint',file_name)
new_model = tf.keras.models.load_model(checkpoint_path)

# %%
new_model.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_29 (Conv2D)           (None, 46, 46, 32)        320
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 23, 23, 32)        0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 23, 23, 32)        128
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 21, 21, 64)        18496
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 10, 10, 64)        256
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 8, 8, 128)         73856
# ...

# %%
pred = new_model.predict(X_test)

# %%
pred[0],y_test[0]
# Out:
# (array([1.2980873e-06, 9.7810227e-10, 2.6093365e-04, 9.2782962e-01,
#         2.0495083e-03, 6.9858514e-02, 3.6313487e-08], dtype=float32),
#  5)

# %% [markdown]
# ***MODEL***

# %% [markdown]
# 1. Dropout to avoid Overfitting
# 2. Dropout is a regularization method that approximates training a large number of neural networks with different architectures in parallel.

# %%
Model3 = tf.keras.models.Sequential([tf.keras.layers.Conv2D(32,(3, 3), activation='relu', input_shape=(48,48,1)),
                                     tf.keras.layers.MaxPool2D((2,2),strides=None),
                                     tf.keras.layers.BatchNormalization(),
                                     tf.keras.layers.Dropout(0.5),
                                        
                                     tf.keras.layers.Conv2D(64,(3, 3), activation='relu', input_shape=(48,48,1)),
                                     tf.keras.layers.MaxPool2D((2,2),strides=None),
                                     tf.keras.layers.BatchNormalization(),
                                     tf.keras.layers.Dropout(0.5),

                                     tf.keras.layers.Conv2D(128,(3, 3), activation='relu', input_shape=(48,48,1)),
                                     tf.keras.layers.MaxPool2D((2,2),strides=None),
                                     tf.keras.layers.BatchNormalization(),
                                     tf.keras.layers.Dropout(0.5),

                                     tf.keras.layers.Conv2D(256,(3, 3), activation='relu', input_shape=(48,48,1)),
                                     tf.keras.layers.MaxPool2D((2,2),strides=None),
                                     tf.keras.layers.BatchNormalization(),
                                     tf.keras.layers.Dropout(0.5),


                                     tf.keras.layers.Flatten(),

                                     tf.keras.layers.Dense(128,activation= 'relu'),
                                     tf.keras.layers.Dropout(0.5),
                                     tf.keras.layers.Dense(7,activation='softmax')])

# %%
Model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 46, 46, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 23, 23, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 10, 64)        256
# ...

# %%
file_name = 'Model3.h5'
checkpoint_path =os.path.join('checkpoint',file_name)

call_backs = tf.keras.callbacks.ModelCheckpoint(filepath =checkpoint_path,
                                               monitor ='val_accuracy',
                                               verbose =1,
                                               save_freq='epoch',
                                               save_best_only = False,
                                               save_weights_only= False,
                                               mode = 'max')

# %%
Model3.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001),
                 loss = 'sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = Model3.fit(X_train,y_train,epochs=100,validation_split = 0.2,batch_size=64,callbacks=call_backs)
# Out:
# Epoch 1/100
# 404/404 [==============================] - 96s 229ms/step - loss: 2.8427 - accuracy: 0.1759 - val_loss: 1.9222 - val_accuracy: 0.2464
#
# Epoch 00001: saving model to checkpoint\Model3.h5
# Epoch 2/100
# 404/404 [==============================] - 85s 210ms/step - loss: 2.4001 - accuracy: 0.1984 - val_loss: 1.8159 - val_accuracy: 0.2480
#
# Epoch 00002: saving model to checkpoint\Model3.h5
# Epoch 3/100
# 404/404 [==============================] - 93s 230ms/step - loss: 2.2120 - accuracy: 0.2060 - val_loss: 1.8246 - val_accuracy: 0.2472
#
# Epoch 00003: saving model to checkpoint\Model3.h5
# Epoch 4/100
# 404/404 [==============================] - 98s 243ms/step - loss: 2.0862 - accuracy: 0.2161 - val_loss: 1.8061 - val_accuracy: 0.2471
#
# Epoch 00004: saving model to checkpoint\Model3.h5
# Epoch 5/100
# 404/404 [==============================] - 103s 256ms/step - loss: 2.0066 - accuracy: 0.2210 - val_loss: 1.8105 - val_accuracy: 0.2478
#
# ...

# %% [markdown]
# #https://stackoverflow.com/questions/51344839/what-is-the-difference-between-the-terms-accuracy-and-validation-accuracy

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
#new_model.summary()

# %% [markdown]
# ***Prediction of Model3***

# %%
y_pred = Model3.predict(X_test)

# %%
#X_test[0].type

# %%
y_pred[0]
# Out:
# array([9.1692538e-20, 0.0000000e+00, 5.0283786e-14, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.7224043e-29], dtype=float32)

# %%
y_test[0]
# Out:
# 1

# %%
max(y_pred[0])
# Out:
# 1.0

# %%
y_pred[1]
# Out:
# array([0.000000e+00, 0.000000e+00, 4.744811e-32, 1.000000e+00,
#        0.000000e+00, 0.000000e+00, 0.000000e+00], dtype=float32)

# %%
max(y_pred[1])
# Out:
# 1.0

# %%
y_test[1]
# Out:
# 3

# %%
#********#
y_list = list(y_pred[0])
#print(X_test[0])
plt.imshow(X_test[0])
label_to_text.keys()
y=str(y_test[0])
print("Original_label==",label_to_text[y])

for i in range(0,7):
    #print(i)
    if y_list[i]==max(y_list):
        #print(label_to_text['0'])
        print("Predicted_label==",label_to_text[str(i)],"\nEmotion_percentage =",round((y_list[i]*100),2),"%")
# Out:
# Original_label== disgust
# Predicted_label== happy
# Emotion_percentage = 100.0 %

# %%
#********#
y_list = list(y_pred[1])
#print(X_test[0])
plt.imshow(X_test[1])
label_to_text.keys()
y=str(y_test[1])
print("Original_label==",label_to_text[y])

for i in range(0,7):
    #print(i)
    if y_list[i]==max(y_list):
        #print(label_to_text['0'])
        print("Predicted_label==",label_to_text[str(i)],"\nEmotion_percentage =",round((y_list[i]*100),2),"%")
# Out:
# Original_label== happy
# Predicted_label== happy
# Emotion_percentage = 100.0 %

# %%
#********#
y_list = list(y_pred[2])
#print(X_test[0])
plt.imshow(X_test[2])
label_to_text.keys()
y=str(y_test[2])
print("Original_label==",label_to_text[y])

for i in range(0,7):
    #print(i)
    if y_list[i]==max(y_list):
        #print(label_to_text['0'])
        print("Predicted_label==",label_to_text[str(i)],"\nEmotion_percentage =",round((y_list[i]*100),2),"%")
# Out:
# Original_label== surprise
# Predicted_label== fear
# Emotion_percentage = 100.0 %

# %% [markdown]
# ***First 10 Predictions***

# %%
def Prediction(label):
    y_list = list(y_pred[label])
    #print(X_test[0])
    plt.imshow(X_test[label])
    label_to_text.keys()
    y=str(y_test[label])
    print("Original_label==",label_to_text[y])
    

    for i in range(0,7):
        #print(i)
        if y_list[i]==max(y_list):
            #print(label_to_text['0'])
            print("Predicted_label ==",label_to_text[str(i)],"\nEmotion_percentage =",round((y_list[i]*100),2),"%")
            plt.show()
    #return plt.imshow(X_test[label])

# %%
#Prediction(1)

# %%
import time
for i in range(0,10):
    Prediction(i)
    time.sleep(0.5)
# Out:
# Original_label== disgust
# Predicted_label == happy
# Emotion_percentage = 100.0 %
# Original_label== happy
# Predicted_label == happy
# Emotion_percentage = 100.0 %
# Original_label== surprise
# Predicted_label == fear
# Emotion_percentage = 100.0 %
# Original_label== sad
# Predicted_label == fear
# Emotion_percentage = 100.0 %
# Original_label== angry
# Predicted_label == angry
# Emotion_percentage = 100.0 %
# Original_label== happy
# Predicted_label == happy
# Emotion_percentage = 100.0 %
# Original_label== fear
# Predicted_label == fear
# Emotion_percentage = 100.0 %
# Original_label== angry
# Predicted_label == fear
# Emotion_percentage = 100.0 %
# Original_label== sad
# Predicted_label == fear
# Emotion_percentage = 100.0 %
# Original_label== neutral
# Predicted_label == angry
# Emotion_percentage = 97.93 %

# %% [markdown]
# ***Data Prep for Confusion Matrix***

# %%
predicted_Emotions = []
for pred_list in y_pred:
    pred_list = list(pred_list)
    #print(pred_list)
    #print(max(pred_list))
    #print("Percentage Emotion=",round(max(pred_list)*100,2),"%")
    for i in range(0,7):
        if pred_list[i]==max(pred_list):
            predicted_Emotions.append(i)
#print(predicted_Emotions)

# %%
#print(predicted_Emotions[:100])

# %%
Pred_Emo = np.array(predicted_Emotions)

# %%
print(Pred_Emo[:10])
# Out:
# [3 3 2 2 0 3 2 2 2 0]

# %%
print(y_test[:10])
# Out:
# [1 3 6 5 0 3 2 0 5 4]

# %% [markdown]
# ***Confusion Matrix***

# %%
# importing the metrics module from sklearn
from sklearn import metrics

# %%
print(metrics.confusion_matrix(y_test, Pred_Emo))
# Out:
# [[ 50   6  13 135 107 100  59]
#  [  7   0   6  15  18   6   4]
#  [ 66   2  19 129 124 112  59]
#  [117   9  25 247 181 202  85]
#  [ 89   6  21 168 130 151  79]
#  [104   7  20 167 137 148  64]
#  [ 46   3  10 108  83  96  49]]

# %%
import numpy as np
import seaborn as sns
def draw_heatmap(confusion_matrix):
  sns.heatmap(conf_mat, annot=True, fmt='d')

# %%
from sklearn.metrics import confusion_matrix, classification_report

conf_mat = confusion_matrix(y_test, Pred_Emo)
draw_heatmap(conf_mat)

#print(classification_report(y_test, Pred_Emo, target_names=raw_train_ds.class_names))

# %% [markdown]
# ***Testing on Real Images***

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('Test1.jpg')

# %%
plt.imshow(image)

# %%
image_Org =cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
image_Org.shape
# Out:
# (338, 509)

# %%
image.shape
# Out:
# (338, 509, 3)

# %%
resized = cv2.resize(image_Org,(48,48))

# %%
resized.shape
# Out:
# (48, 48)

# %%
plt.imshow(resized)

# %%
img_array = np.array(resized)

# %%
#print(img_array)

# %%
img_array = img_array/255

# %%
#print(img_array)
img_array.shape
# Out:
# (48, 48)

# %%
img_array = img_array.reshape(img_array.shape[0],48,1)

# %%
img_array.shape
# Out:
# (48, 48, 1)

# %%
#Model3.predict(img_array)
