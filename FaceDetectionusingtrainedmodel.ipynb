# %%
import tensorflow as tf

# %%
final_model = tf.keras.models.load_model("Model3.h5")

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('Test1.jpg')
image_Org =cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(image_Org)

# %%
import numpy as np
rsz = np.resize(image_Org,(1,48,48))

# %%
y_pred = final_model.predict(rsz)

# %%
y_pred
# Out:
# array([[2.54749738e-16, 0.00000000e+00, 1.00000000e+00, 1.10133636e-13,
#         2.37319755e-31, 1.99328992e-27, 2.98981578e-36]], dtype=float32)

# %%
Percentage_emotion = round((max(y_pred[0])*100),2)
print(Percentage_emotion)
# Out:
# 100.0

# %%
label_to_text={'0':'angry','1':'disgust','2':'fear','3':'happy','4':'neutral','5':'sad','6':'surprise'}

# %%
y_list = list(y_pred[0])

# %%
for i in range(0,7):
    #print(i)
    if y_list[i]==max(y_list):
        #print(label_to_text['0'])
        print("Predicted_label ==",label_to_text[str(i)],";","Emotion_percentage ==",round((y_list[i]*100),2),"%")
# Out:
# Predicted_label == fear ; Emotion_percentage == 100.0 %

# %%
# Load the classifier and create a cascade object for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml')

# %%
faces = face_cascade.detectMultiScale(image_Org,1.1,4)

# %%
for(x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w, y+w),(0,255,0),2)

# %%
#faces = face_cascade.detectMultiScale(rsz, scaleFactor=1.25, minNeighbors=3, minSize=(48,48))

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
cv2.putText(image,"face",(0,200),font,1,(0,255,0),2,cv2.LINE_4);
for i in range(0,7):
    #print(i)
    if y_list[i]==max(y_list):
        #print(label_to_text['0'])
        perc = int(round((y_list[i]*100),2))
        print(perc)
        cv2.putText(image,label_to_text[str(i)]+'='+str(perc)+'%',(0,200),font,1,(0,255,0),2,cv2.LINE_4);
                #print("Predicted_label ==",label_to_text[str(i)],";","Emotion_percentage ==",round((y_list[i]*100),2),"%")
# Out:
# 100

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
###Eye cascade xml File
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml
###Frontal cascade xml File
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Out:
# --2021-11-27 20:33:22--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 341406 (333K) [text/plain]
# Saving to: ‘haarcascade_eye.xml.1’
#
# haarcascade_eye.xml 100%[===================>] 333.40K  --.-KB/s    in 0.003s
#
# 2021-11-27 20:33:22 (97.3 MB/s) - ‘haarcascade_eye.xml.1’ saved [341406/341406]
#
# --2021-11-27 20:33:22--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# ...

# %%
import cv2
from urllib.request import urlopen
import numpy as np
from google.colab.patches import cv2_imshow

# %%
#cascades_path = 'drive/xxx/'
# Load the cascade
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')
# Read the input image
req = urlopen('https://tvseriesfinale.com/wp-content/uploads/2014/04/siliconvalley03-590x331.jpg')
arr = np.asarray(bytearray(req.read()), dtype=np.uint8)
img = cv2.imdecode(arr, -1) # 'Load it as it is'
result_image = img.copy()

# %%
# Convert frame to grayscale:
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.1, 4)

# %%
# Iterate over each detected face:
for (x, y, w, h) in faces:
        # Draw a rectangle  to see the detected face (debugging purposes):
        cv2.rectangle(img, (x, y), (x + w, y + h), (255, 255, 0), 2)

# Display the resulting frame
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=590x331 at 0x7FB16B2694D0>

# %%
#cascades_path = 'drive/my-drive/'
face_crop = []
# Load the cascade
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades  +'haarcascade_frontalface_default.xml')
# Read the input image
req = urlopen('https://tvseriesfinale.com/wp-content/uploads/2014/04/siliconvalley03-590x331.jpg')
arr = np.asarray(bytearray(req.read()), dtype=np.uint8)
img = cv2.imdecode(arr, -1) # 'Load it as it is'
result_image = img.copy()
#img = cv2.imread('https://intrasee.com/wp-content/uploads/2016/08/silicon-valley-hero.jpg')
# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.1, 4)
print(faces)

# Iterate over each detected face:
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Display the resulting frame
cv2_imshow(img)
# Out:
# [[346  26  49  49]
#  [450  30  50  50]
#  [184  37  47  47]
#  [256  56  48  48]
#  [105  63  53  53]]
# <PIL.Image.Image image mode=RGB size=590x331 at 0x7FB16B234510>

# %%
def Prediction(label):
    y_list = list(y_pred[label])
    #print(X_test[0])
    plt.imshow(X_test[label])
    label_to_text.keys()
    y=str(y_test[label])
    print("Original_label==",label_to_text[y])
    

    for i in range(0,7):
        #print(i)
        if y_list[i]==max(y_list):
            #print(label_to_text['0'])
            print("Predicted_label ==",label_to_text[str(i)],"\nEmotion_percentage =",round((y_list[i]*100),2),"%")
            plt.show()

# %%
face_crop = []
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    face_crop.append(gray[y:y+h, x:x+w])

#Predicted=[]
for face in face_crop:
   cv2_imshow(face)
   #image_Org =cv2.cvtColor(face, cv2.COLOR_RGB2GRAY)
   #rsz = np.resize(image_Org,(1,48,48))
   #pred = final_model.predict(rsz)
   #Predicted.append(pred)
   
   rsz = np.resize(face,(1,48,48))
   #print(rsz.shape)
   y_pred = final_model.predict(rsz)
   y_list = list(y_pred[0])
    #print(X_test[0])
   #plt.imshow(X_test[0])
   label_to_text.keys()
   #y=str(y_test[label])
   #print("Original_label==",label_to_text[y])
    

   for i in range(0,7):
        #print(i)
        if y_list[i]==max(y_list):
            #print(label_to_text['0'])
            print("Predicted_label ==",label_to_text[str(i)],"\nEmotion_percentage =",round((y_list[i]*100),2),"%")
            plt.show()
    #return plt.imshow(X_test[label])
# Out:
# <PIL.Image.Image image mode=L size=49x49 at 0x7FB16BDE3790>
# Predicted_label == fear
# Emotion_percentage = 100.0 %
# <PIL.Image.Image image mode=L size=50x50 at 0x7FB16BDFEF50>
# Predicted_label == fear
# Emotion_percentage = 93.95 %
# <PIL.Image.Image image mode=L size=47x47 at 0x7FB16BD3AA90>
# Predicted_label == angry
# Emotion_percentage = 99.96 %
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB16BD2ED10>
# Predicted_label == fear
# Emotion_percentage = 100.0 %
# <PIL.Image.Image image mode=L size=53x53 at 0x7FB16BCEB110>
# Predicted_label == fear
# Emotion_percentage = 100.0 %

# %%
label_to_text={'0':'angry','1':'disgust','2':'fear','3':'happy','4':'neutral','5':'sad','6':'surprise'}

# %%
y_list = Predicted[0]

# %%
len(y_list)
# Out:
# 1

# %%
y_list[0]
# Out:
# array([1.8880212e-24, 0.0000000e+00, 9.9995196e-01, 4.8024267e-05,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00], dtype=float32)

# %%
max(y_list[0])
# Out:
# 0.99995196

# %%
for i in range(0,7):
    #print(i)
    if y_list[i]==max(y_list):
        #print(label_to_text['0'])
        print("Predicted_label ==",label_to_text[str(i)],";","Emotion_percentage ==",round((y_list[i]*100),2),"%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-193-5001fc23183e> in <module>()
#       1 for i in range(0,7):
#       2     #print(i)
# ----> 3     if y_list[i]==max(y_list):
#       4         #print(label_to_text['0'])
#       5         print("Predicted_label ==",label_to_text[str(i)],";","Emotion_percentage ==",round((y_list[i]*100),2),"%")
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
